# %%
import matplotlib.pyplot as plt
import numpy as np


n = np.arange(50)
dt = 0.07/50
x = np.sin(2 * np.pi * 50 * n * dt)
plt.xlabel('n')
plt.ylabel('x[n]')
plt.title(r'Plot of DT signal \$x[n] = 325 \sin(2\pi 50 n \Delta t)\$');

plt.stem(n, x); #for discrete plots
#plt.plot(n,x) - for continuous plots

# %%
import matplotlib.pyplot as plt
import numpy as np
  
x = np.linspace(0.1, 2 * np.pi, 41)
y = np.exp(np.sin(x))
  
plt.stem(x, y,use_line_collection = True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
  
x = np.linspace(0.1, 2 * np.pi, 20)
y = np.exp(np.sin(x))
  
plt.stem(x, y,use_line_collection = True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
  
x = np.linspace(0.1, 2 * np.pi, 41)
y = np.exp(x)
  
plt.stem(x, y,use_line_collection = True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
  
x = np.linspace(0.1, 2 * np.pi, 41)
y = np.sin(x)
  
plt.stem(x, y,use_line_collection = True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
  
x = np.linspace(0.1, 2 * np.pi, 41)
y = np.cos(x)
  
plt.stem(x, y,use_line_collection = True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
  
x = np.linspace(0.1, 2 * np.pi, 41)
y = np.tan(x)
  
plt.stem(x, y,use_line_collection = True)
plt.show()
